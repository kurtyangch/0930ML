# %% [markdown]
# <a href="https://colab.research.google.com/github/kurtyangch/0930ML/blob/master/%E3%80%8Cregression_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_boston 
boston=load_boston()
# 函式庫modin處理巨量資料
# 拿到資料先處理成表格
df=pd.DataFrame(boston["data"], columns=boston["feature_names"])
df["target"] = boston["target"]
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  target
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98    24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14    21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03    34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94    33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33    36.2
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...     ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67    22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08    20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64    23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48    22.0
# ...

# %%
# 預處理: pandas/DataFrame
# 機器學習: numpy/np.array
import numpy as np
from sklearn.model_selection import train_test_split
x, y =df.drop(["target"], axis=1), df["target"]
x, y = np.array(x), np.array(y)
x_treain, x_test,y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
clf= DecisionTreeClassifier()
clf.fit(x_treain, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-bc52a52a6739> in <module>()
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 clf= DecisionTreeClassifier()
# ----> 3 clf.fit(x_treain, y_train)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     171
#     172         if is_classification:
# --> 173             check_classification_targets(y)
#     174             y = np.copy(y)
#     175
#
# ...

# %%
import graphviz
from sklearn.tree import export_graphviz
g = export_graphviz(clf, 
           feature_names=boston["feature_names"],
           class_names=boston["target_names"],
           filled=True)
graphviz.Source(g)

# %%
from sklearn.metrics import accuracy_score
pre = clf.predict(x_test)
accuracy_score(pre, y_test)
